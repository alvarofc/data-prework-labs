# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
import random
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
possibilities = ["R", "P", "S"]
max_games = 3
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
win = max_games /2 + 0.5
# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def ran(my_list):
    return random.choice(my_list)

# %%
# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def choose():
    while True:
        global hu
        hu = input("choose Rock [R], Paper [P] or Scissors [S]: ")
        if hu in ['R', 'P', 'S']:
            break
        else:
            print("Wrong input. R/S/P")
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat():
    global r
    r = ran(possibilities)
    if hu == r:
        return 0
    elif hu == 'P' and r == 'R':
        return 2
    elif hu == 'P' and r == 'S':
        return 1
    elif hu == 'R' and r == 'S':
        return 2
    elif hu == 'R' and r == 'P':
        return 1 
    elif hu == 'S' and r == 'R':
        return 1 
    elif hu == 'S' and r == 'P':
        return 2
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def scoreboard():
    if c == 1:
        print("You chose,", hu, "the computer chose",r,". The computer wins this round")
    elif c == 2:
        print("You chose,", hu, "the computer chose",r,". You win this round, lucky human...")
    elif c == 0:
        print("You chose,", hu, "the computer chose",r,". It's a tie")
    else:
        pass
            
    
    
# Create two variables that accumulate the wins of each participant
wins_h = 0 
wins_c = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while wins_h < win and wins_c < win: 
    choose()
    c = combat()
    c
    scoreboard()
    if c == 1:
        wins_c +=1 
    elif c == 2:
        wins_h += 1
    else:
        pass
    
# Print by console the winner of the game based on who has more accumulated wins
def winner():
    if wins_h >= win:
        print("Human wins this time... The final score is:", wins_h,"-",wins_c)
    elif wins_c >= win:
        print("COMPUTER WINS!!! The final score is:", wins_h,"-",wins_c)
    else:
        pass
winner()
# Out:
# choose Rock [R], Paper [P] or Scissors [S]: P
# You chose, P the computer chose R . You win this round, lucky human...
# choose Rock [R], Paper [P] or Scissors [S]: P
# You chose, P the computer chose S . The computer wins this round
# choose Rock [R], Paper [P] or Scissors [S]: P
# You chose, P the computer chose R . You win this round, lucky human...
# choose Rock [R], Paper [P] or Scissors [S]: P
# You chose, P the computer chose R . You win this round, lucky human...
# Human wins this time... The final score is: 3 - 1

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def number():
    while True:
        global games
        num = int(input("Enter an odd number to define the maximum amount of games: "))
        if num %2 > 0:
            print("We are going to play", num, "games.")
            games = num
            break
        else:
            print("You entered an even number")
number()
# Assign a list of 5 possible options.
possibilities_2 = ["R", "P", "S", "L","Sp"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_games_2 = games

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
win_2 = max_games_2 /2 + 0.5

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
    #ran(possibilities_2)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def choose_2():
    while True:
        global hu_2
        hu_2 = input("Choose Rock [R], Paper [P], Scissors [S], Lizard [L] or Spock [Sp] : ")
        if hu_2 in ['R', 'P', 'S', 'L', 'Sp']:
            break
        else:
            print("Wrong input. R/S/P/L/Sp")

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combat_2():
    global r_2
    r_2 = ran(possibilities_2)
    if hu_2 == r_2:
        return 0
    elif hu_2 == 'P' and r_2 == 'R':
        return 2
    elif hu_2 == 'P' and r_2 == 'S':
        return 1
    elif hu_2 == 'P' and r_2 =='Sp':
        return 2
    elif hu_2 == 'P' and r_2 == 'L':
        return 1
    elif hu_2 == 'R' and r_2 == 'S':
        return 2
    elif hu_2 == 'R' and r_2 == 'P':
        return 1 
    elif hu_2 == 'R' and r_2 == 'L':
        return 2 
    elif hu_2 == 'R' and r_2 == 'Sp':
        return 1 
    elif hu_2 == 'S' and r_2 == 'R':
        return 1 
    elif hu_2 == 'S' and r_2 == 'P':
        return 2
    elif hu_2 == 'S' and r_2 == 'L':
        return 2
    elif hu_2 == 'S' and r_2 == 'Sp':
        return 1 
    elif hu_2 =='L' and r_2 == 'R':
        return 1
    elif hu_2 =='L' and r_2 == 'P':
        return 2
    elif hu_2 =='L' and r_2 == 'S':
        return 1 
    elif hu_2 =='L' and r_2 == 'Sp':
        return 2 
    elif hu_2 =='Sp' and r_2 == 'R':
        return 2 
    elif hu_2 =='Sp' and r_2 == 'P':
        return 1
    elif hu_2 =='Sp' and r_2 == 'S':
        return 2 
    elif hu_2 =='Sp' and r_2 == 'L':
        return 1
    else:
        print(hu_2, r_2)

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def scoreboard_2():
    if c_2 == 1:
        print("You chose,", hu_2, "the computer chose",r_2,". The computer wins this round")
    elif c_2 == 2:
        print("You chose,", hu_2, "the computer chose",r_2,". You win this round, lucky human...")
    elif c_2 == 0:
        print("You chose,", hu_2, "the computer chose",r_2,". It's a tie")
    else:
        pass
    
# Create two variables that accumulate the wins of each participant
wins_computer = 0 
wins_human = 0
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while wins_human < win_2 and wins_computer < win_2: 
    choose_2()
    c_2 = combat_2()
    c_2
    scoreboard_2()
    if c_2 == 1:
        wins_computer +=1 
    elif c_2 == 2:
        wins_human += 1
    else:
        pass
    
    
    
# Print by console the winner of the game based on who has more accumulated wins
def winner_2():
    if wins_human >= win_2:
        print("Human wins this time... The final score is:", wins_human,"-",wins_computer)
    elif wins_computer >= win_2:
        print("COMPUTER WINS!!! The final score is:", wins_human,"-",wins_computer)
    else:
        pass
winner_2()
# Out:
# Enter an odd number to define the maximum amount of games: 5
# We are going to play 5 games.
# Choose Rock [R], Paper [P], Scissors [S], Lizard [L] or Spock [Sp] : P
# You chose, P the computer chose L . The computer wins this round
# Choose Rock [R], Paper [P], Scissors [S], Lizard [L] or Spock [Sp] : L
# You chose, L the computer chose R . The computer wins this round
# Choose Rock [R], Paper [P], Scissors [S], Lizard [L] or Spock [Sp] : Sp
# You chose, Sp the computer chose L . The computer wins this round
# COMPUTER WINS!!! The final score is: 0 - 3
